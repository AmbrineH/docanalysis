# %%
# !rm -rf /content/docanalysis
# !git clone https://github.com/AmbrineH/docanalysis.git /content/docanalysis
# %cd /content/docanalysis
# !pip install --upgrade pip setuptools wheel
# !pip install -r requirements.txt
# !pip install -e .
# Out:
# Cloning into '/content/docanalysis'...
# remote: Enumerating objects: 2440, done.
# remote: Counting objects: 100% (422/422), done.
# remote: Compressing objects: 100% (158/158), done.
# remote: Total 2440 (delta 298), reused 372 (delta 261), pack-reused 2018 (from 1)
# Receiving objects: 100% (2440/2440), 2.76 MiB | 6.58 MiB/s, done.
# Resolving deltas: 100% (997/997), done.
# /content/docanalysis
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 18.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 46.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.2.0
#     Uninstalling setuptools-75.2.0:
#       Successfully uninstalled setuptools-75.2.0
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...

# %%
# %cd /content/docanalysis

# Always good to have the latest installer tooling
#!pip install --upgrade pip setuptools wheel

# Install everything your repo declares
# !pip install -r requirements.txt

# Now install your package in “editable” mode
# !pip install -e .
# Out:
# /content/docanalysis
# ...
# Obtaining file:///content/docanalysis
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: docanalysis
#     Found existing installation: docanalysis 0.3.0
#     Uninstalling docanalysis-0.3.0:
#       Successfully uninstalled docanalysis-0.3.0
#   DEPRECATION: Legacy editable install of docanalysis==0.3.0 from file:///content/docanalysis (setup.py develop) is deprecated. pip 25.1 will enforce this behaviour change. A possible replacement is to add a pyproject.toml or enable --use-pep517, and use setuptools >= 64. If the resulting installation is not behaving as expected, try using --config-settings editable_mode=compat. Please consult the setuptools documentation for more information. Discussion can be found at https://github.com/pypa/pip/issues/11457
#   Running setup.py develop for docanalysis
# ...

# %%
import docanalysis
print("docanalysis package is installed and imported successfully.")
# Out:
# docanalysis package is installed and imported successfully.

# %%
# Show the help text (verifies it’s your latest code)
# !python -m docanalysis.docanalysis --help
# Out:
# /usr/local/lib/python3.11/dist-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils. Support for replacing an already imported distutils is deprecated. In the future, this condition will fail. Register concerns at https://github.com/pypa/setuptools/issues/new?template=distutils-deprecation.yml
#   warnings.warn(
# <frozen runpy>:128: RuntimeWarning: 'docanalysis.docanalysis' found in sys.modules after import of package 'docanalysis', but prior to execution of 'docanalysis.docanalysis'; this may result in unpredictable behaviour
# usage: docanalysis.py [-h] [--run_pygetpapers] [--make_section] [-q QUERY]
#                       [-k HITS] [--project_name PROJECT_NAME]
#                       [-d [DICTIONARY ...]] [-o OUTPUT]
#                       [--make_ami_dict MAKE_AMI_DICT]
#                       [--search_section [SEARCH_SECTION ...]]
#                       [--entities [ENTITIES ...]] [--spacy_model SPACY_MODEL]
# ...

# %%
# !python -m docanalysis.docanalysis \
    --run_pygetpapers \
    -q "terpene" \
    -k 10 \
    --project_name terpene_10 \
    --make_section
# Out:
# /usr/local/lib/python3.11/dist-packages/_distutils_hack/__init__.py:30: UserWarning: Setuptools is replacing distutils. Support for replacing an already imported distutils is deprecated. In the future, this condition will fail. Register concerns at https://github.com/pypa/setuptools/issues/new?template=distutils-deprecation.yml
#   warnings.warn(
# <frozen runpy>:128: RuntimeWarning: 'docanalysis.docanalysis' found in sys.modules after import of package 'docanalysis', but prior to execution of 'docanalysis.docanalysis'; this may result in unpredictable behaviour
# INFO: Total Hits are 22533
# 10it [00:00, 83220.32it/s]
# INFO: Saving XML files to /content/docanalysis/terpene_10/*/fulltext.xml
# 100% 10/10 [00:16<00:00,  1.61s/it]
# INFO: making CProject /content/docanalysis/terpene_10 with 10 papers on terpene
# WARNING: Making sections in /content/docanalysis/terpene_10/PMC11945410/fulltext.xml
# ...
